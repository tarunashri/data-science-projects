# %%
import pandas as pd

# %%
df = pd.read_csv("Hypermart.csv", encoding='ISO-8859-1')# pandas reads the UTF encoded files only.

# %%
# basic analysis

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# from the summary,we can see that
# Sales and profit figures vary significantly, with some products incurring negative profits.
# Discounts range between 0.0 and 0.8, suggesting that high discounts might be affecting profits.
# There is a large range in sales and quantities, indicating that some products dominate the sales compared to others.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# question -1 Identify if the dataset contains any missing data, inconsistencies in the values for a given attribute.
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
df.drop_duplicates()# if in case there is duplicate row it drops it 
# so as the size remains same there are no duplicate rows
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# Duplicate rows can create a error in  analysis, especially when calculating totals like sales, profit, and quantity.
# Removing them will ensure that  values are unique, giving more accurate and reliable insights.
# After dropping duplicates, the dataset becomes clean and easy for further analysis.

# %%
df.drop(columns=['Row ID'])# we drop the unnecessary column row id as it is same as index 
#it does not have any analytical values with it in the dataset
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1     CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2     CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03-03-2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05-04-2017  05-09-2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# a data cleaning step to improve efficiency and avoid confusion.it helps us to only have the columns which have potential to give us further analysis

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# question -2 Identify if the dataset contains any missing data, inconsistencies in the values for a given attribute.
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df.isna().sum()# it gives  how many missing values are present in the each column
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.dropna()# drops the  rows with missing data.
df.fillna(0)# fills the missing values with 0 .
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# No missing values were detected, indicating a well-maintained dataset.
# If missing data had been present, we would have handled it using either row removal or changing the value .

# %%
# for checking the data, we can take all the unique values in the rows and then check if there are typo errors ,extraspace or inconsistence casting
print("the different values in shipmode column are " ,df['Ship Mode'].unique())
print("the different values in segment column are " ,df['Segment'].unique())
print("the different values in  country  column are " ,df['Country'].unique())
print("the different values in state column are " ,df['State'].unique())
print("the different values in region column are " ,df['Region'].unique())
print("the different values in category column are " ,df['Category'].unique())
print("the different values in sub-category column are " ,df['Sub-Category'].unique())
# Out:
# the different values in shipmode column are  ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# the different values in segment column are  ['Consumer' 'Corporate' 'Home Office']
# the different values in  country  column are  ['United States']
# the different values in state column are  ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']
# the different values in region column are  ['South' 'West' 'Central' 'East']
# ...

# %%
#print("the different values in city  column are " ,df['City'].unique()) 
#this has hundreads of city names so instead of finding the names and then cleaning it 
#we directly remove the spaces as well as convert them into smaller case
df['City'] = df['City'].str.strip().str.lower()
print("city;\n",df['City'].drop_duplicates())
# Out:
# city;
#  0             henderson
# 2           los angeles
# 3       fort lauderdale
# 12              concord
# 13              seattle
#              ...
# 9667       san clemente
# 9701    san luis obispo
# 9760         springdale
# 9801               lodi
# 9868              mason
# Name: City, Length: 531, dtype: object

# %%
#likewise the above let me clean the data set and make it consistence for the other columns also 
df['Ship Mode'] = df['Ship Mode'].str.strip().str.lower()
print("Ship Mode:\n", df['Ship Mode'].drop_duplicates())
df['Segment'] = df['Segment'].str.strip().str.lower()
print("\nSegment:\n", df['Segment'].drop_duplicates())
df['Country'] = df['Country'].str.strip().str.lower()
print("\nCountry:\n", df['Country'].drop_duplicates())
df['City'] = df['City'].str.strip().str.lower()
print("\nCity:\n", df['City'].drop_duplicates())
df['State'] = df['State'].str.strip().str.lower()
print("\nState:\n", df['State'].drop_duplicates())
df['Region'] = df['Region'].str.strip().str.lower()
print("\nRegion:\n", df['Region'].drop_duplicates())
df['Category'] = df['Category'].str.strip().str.lower()
print("\nCategory:\n", df['Category'].drop_duplicates())
df['Sub-Category'] = df['Sub-Category'].str.strip().str.lower()
print("\nSub-Category:\n", df['Sub-Category'].drop_duplicates())
# Out:
# Ship Mode:
#  0        second class
# 3      standard class
# 35        first class
# 366          same day
# Name: Ship Mode, dtype: object
#
# Segment:
#  0        consumer
# 2       corporate
# 14    home office
# Name: Segment, dtype: object
#
# Country:
#  0    united states
# Name: Country, dtype: object
#
# City:
#  0             henderson
# 2           los angeles
# 3       fort lauderdale
# 12              concord
# 13              seattle
#              ...
# 9667       san clemente
# 9701    san luis obispo
# 9760         springdale
# 9801               lodi
# 9868              mason
# Name: City, Length: 531, dtype: object
#
# State:
#  0                   kentucky
# 2                 california
# 3                    florida
# 12            north carolina
# 13                washington
# 14                     texas
# 16                 wisconsin
# 17                      utah
# 21                  nebraska
# 23              pennsylvania
# 41                  illinois
# ...

# %% [markdown]
# **Insight:**
# All categorical values are now uniform,which  reduces risk of duplicate categorie due to case/space differences.
# This step ensures accuracy in grouping, filtering, and visualization for next analysis

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------
#  data analysis using numpy, Pandas, Matplotlib and Seaborn
#  -------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# Data distribution and Trends
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  Products Having the Highest Sales but Low or Negative Profit Margins

# %%
columns_2 = df.groupby('Product Name')[['Sales', 'Profit']].sum().reset_index()
low_profit = columns_2[columns_2['Profit'] <= 0]
top_low_profit = low_profit.sort_values(by='Sales', ascending=False)
print(top_low_profit.head(10))

plt.figure(figsize=(12, 6))
sns.barplot(data=top_low_profit.head(10), x='Sales', y='Product Name', hue='Product Name', palette='Reds_r', legend=False)
plt.title('Top 10 Products with High Sales but Low/Negative Profit')
plt.xlabel('Total Sales')
plt.ylabel('Product Name')
plt.tight_layout()
plt.show()
# Out:
#                                            Product Name       Sales     Profit
# 444   Cisco TelePresence System EX90 Videoconferenci...  22638.4800 -1811.0784
# 683           GBC DocuBind P400 Electric Binding System  17965.0680 -1878.1662
# 813         High Speed Automatic Electric Letter Opener  17030.3120  -262.0048
# 985           Lexmark MX611dhe Monochrome Laser Printer  16829.9010 -4589.9730
# 1043  Martin Yale Chadless Opener Electric Letter Op...  16656.2000 -1299.1836
# 1351  Riverside Palais Royal Lawyers Bookcase, Royal...  15610.9656  -669.5448
# 368          Bretford Rectangular Conference Table Tops  12995.2915  -327.2331
# 475           Cubify CubeX 3D Printer Double Head Print  11099.9630 -8879.9704
# 425   Chromcraft Bull-Nose Wood Oval Conference Tabl...   9917.6400 -2876.1156
# 376   Bush Advantage Collection Racetrack Conference...   9544.7250 -1934.3976

# %% [markdown]
# **Insight:** That indicates that most sales are of lower value, and a few big items contribute to revenue. There are several products that, despite generating high sales, have low or negative profit margins. This shows potential pricing or cost issues with these specific items, and they may require re-evaluation of pricing strategy or cost control measures to ensure profitability.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Product Categories Having the Highest Sales Volume

# %%
category_volume = df.groupby('Category')['Quantity'].sum().reset_index()
print(category_volume )
#plot
sns.barplot(data=category_volume, x='Quantity', y='Category', hue='Category', palette='Set2', legend=False)
plt.title('Total Quantity Sold by Product Category')
plt.ylabel('Quantity Sold')
plt.xlabel('Category')
plt.show()
# Out:
#           Category  Quantity
# 0        furniture      8028
# 1  office supplies     22906
# 2       technology      6939

# %% [markdown]
# **Insight:**
# The Office Supplies category has the highest sales volume in terms of quantity sold, followed by Technology and then Furniture.
# This suggests that Office Supplies are the most frequently purchased products, possibly due to lower prices and regular restocking needs.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Does Shipping Mode Impact Order Delivery Time

# %%
#converting from string form to dateform 
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=False, errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=False, errors='coerce')

df['Delivery Time'] = (df['Ship Date'] - df['Order Date']).dt.days
shipping = df.groupby('Ship Mode')['Delivery Time'].mean().reset_index()
shipping =shipping.sort_values(by='Delivery Time', ascending=False)
print(shipping)

# Plotting
plt.figure(figsize=(8, 5))
sns.barplot(data=shipping, x='Delivery Time', y='Ship Mode', hue='Ship Mode', palette='Blues', legend=False)
plt.title('Average Delivery Time by Shipping Mode')
plt.xlabel('Average Delivery Time (Days)')
plt.ylabel('Shipping Mode')
plt.tight_layout()
plt.show()
# Out:
#         Ship Mode  Delivery Time
# 3  standard class       4.775035
# 2    second class       3.186691
# 0     first class       2.074766
# 1        same day       0.065306

# %% [markdown]
# **Insight:**
# The bar plot clearly shows that Standard Class has the longest average delivery time, followed by Second Class, First Class, and Same Day.
# This indicates that Shipping Mode significantly impacts delivery time, with faster modes like Same Day and First Class offering quicker delivery, while Standard Class takes the longest.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  Monthly Sales Trend (Seasonal Patterns)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', errors='coerce')
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month_name()
heatmap_data = df.pivot_table(values='Sales', index='Month', columns='Year', aggfunc='sum')
from calendar import month_name
ordered_months = list(month_name)[1:]  # month_name[0] is empty string
heatmap_data = heatmap_data.reindex(ordered_months)

# Plotting 
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='.0f', linewidths=.5)
plt.title('Monthly Sales Trend (Heatmap)')
plt.xlabel('Year')
plt.ylabel('Month')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The heatmap reveals seasonal sales patterns, with consistent peaks observed in the months of November and December across multiple years.
# This indicates a strong year-end buying trend, possibly due to holiday seasons or promotional events

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Discount vs Profit Scatter Plot

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Discount', y='Profit', hue='Category', palette='Set1')
plt.title('Discount vs Profit (by Category)')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The scatter plot shows that higher discounts often correlate with lower or negative profits, especially within some categories.
# we can see clearly, as discount increases beyond 20-30%, the profit tends to sharply decline, and several points even fall into the loss zone (negative profit).

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  Sales Distribution

# %%
# Calculate 95th percentile to remove outliers
threshold = df['Sales'].quantile(0.95)
filtered_df = df[df['Sales'] <= threshold]

# Plot after removing outliers
plt.figure(figsize=(8, 5))
sns.histplot(filtered_df['Sales'], bins=40, kde=True, color='skyblue')
plt.title('Distribution of Sales (Without Outliers)')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The sales distribution (after removing the top 5% outliers)  it indicates that most transactions have lower sales values, while high-value sales are relatively rare.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Top Cities by Total Sales

# %%
top_cities = df.groupby('City')['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False).head(10)

plt.figure(figsize=(10, 5))
sns.barplot(data=top_cities, x='Sales', y='City', hue='City', palette='magma', legend=False)
plt.title('Top 10 Cities by Total Sales')
plt.xlabel('Sales')
plt.ylabel('City')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
# The bar plot reveals that New York and Los Angeles are the top-performing cities in terms of total sales, followed by cities like Seattle and San Francisco. These cities contribute significantly to overall revenue

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Customer Segmentation & Regional Insights
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  Which Customer Segment generates the highest Sales and Profit?

# %%
segment_sales_profit = df.groupby('Segment')[['Sales', 'Profit']].sum().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
segment_sales_profit_melted = segment_sales_profit.melt(id_vars='Segment', value_vars=['Sales', 'Profit'])
sns.barplot(data=segment_sales_profit_melted, x='Segment', y='value', hue='variable', palette='Set2')
plt.title('Total Sales and Profit by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Amount')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The bar plot shows that the Consumer segment generates the highest total Sales, while the Corporate segment shows the highest Profit. This indicates that although consumers buy more, corporate clients contribute more efficiently to profitability.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# What is the repeat purchase behaviour of customers in each segment?

# %%
repeat_customers = df.groupby(['Segment', 'Customer ID'])['Order ID'].nunique().reset_index()
avg_repeat_orders = repeat_customers.groupby('Segment')['Order ID'].mean().reset_index()

# Plotting
plt.figure(figsize=(8, 5))
sns.barplot(data=avg_repeat_orders, x='Segment', y='Order ID', hue='Segment', palette='coolwarm', legend=False)
plt.title('Average Number of Orders per Customer in Each Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Average Repeat Orders')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The bar plot reveals that Corporate and Home Office customers have slightly higher average repeat purchases compared to Consumers.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Do certain segments respond better to Discounts?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Discount', y='Profit', hue='Segment', palette='Dark2', alpha=0.7)
plt.title('Discount vs Profit across Segments')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The scatter plot reveals that Home Office and Consumer segments shows sharper drops in profit as discounts increase, whereas the Corporate segment appears to be slightly more resilient to discounting.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  region which brings in the most Sales and Profit

# %%
region_sales_profit = df.groupby('Region')[['Sales', 'Profit']].sum().reset_index()

plt.figure(figsize=(10, 6))
region_sales_profit_melted = region_sales_profit.melt(id_vars='Region', value_vars=['Sales', 'Profit'])
sns.barplot(data=region_sales_profit_melted, x='Region', y='value', hue='variable', palette='viridis')
plt.title('Sales and Profit by Region')
plt.ylabel('Amount')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The Central region leads in both sales and profit, which indicates it is the strongest performing market. While the South and West follow closely in sales, their profit margins are lower

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# discounts higher in any segment compared to others

# %%
avg_discount = df.groupby('Segment')['Discount'].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(data=avg_discount, x='Segment', y='Discount', hue='Segment', palette='pastel', legend=False)
plt.title('Average Discount Given by Segment')
plt.ylabel('Average Discount')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The consumer segment receives the highest average discounts, which suggests us that  promotional efforts are more heavily targeted toward this group. whereas the corporate and home office segments receive comparatively lower discounts.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# Growth Opportunities & Market Expansion
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Can Pricing Strategies Be Adjusted Based on Regional Demand?

# %%
region_sales = df.groupby('Region')['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(data=region_sales, y='Region', x='Sales', hue='Region', palette='YlGnBu', legend=False)
plt.title('Total Sales by Region')
plt.xlabel('Sales')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# This bar chart shows that the West region leads in total sales,which indicates the strong demand. where as  the South and Central regions have significantly lower sales.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Are there customer segments in underperforming regions needing targeted marketing?

# %%
region_segment = df.groupby(['Region', 'Segment'])[['Sales', 'Profit']].sum().reset_index()

# Use keyword arguments for pivot
pivot_data = region_segment.pivot(index='Region', columns='Segment', values='Profit')

# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_data, cmap='RdYlGn', annot=True, fmt=".0f")
plt.title('Profit by Segment and Region')
plt.xlabel('Customer Segment')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The heatmap reveals that Corporate and Home Office segments in the Central region show  low or negative profits, so these are the targets for improved marketing strategies. whereas, Consumer segments in the West and East regions are performing well, which tells us that existing strategies are effective there.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#  Which regions have untapped potential based on profitability?

# %%
profit_by_region = df.groupby('Region')['Profit'].sum().reset_index().sort_values(by='Profit')

plt.figure(figsize=(8, 5))
sns.barplot(data=profit_by_region, x='Profit', y='Region', hue='Region', palette='coolwarm', legend=False)
plt.title('Total Profit by Region')
plt.xlabel('Profit')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight :**
# The Central region shows the lowest overall profit which tells us to check the inefficiency in that region. The West region leads in profitability which tells us that the strategies adapted worked very well as profit is high.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# Delivery Time vs Profitability

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Delivery Time', y='Profit', hue='Ship Mode', palette='Dark2', legend=False)
plt.title('Delivery Time vs Profitability')
plt.xlabel('Delivery Time (Days)')
plt.ylabel('Profit')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# the scatter plot shows that longer delivery times generally is proportional to lower or even negative profits. Faster deliveries tend to  show high profits which tell us that optimizing delivery speed could enhance profitability.

# %% [markdown]
# ------

# %% [markdown]
# High Discount, Low Profit Categories

# %%
category_discounts = df.groupby('Category')[['Discount', 'Profit']].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.scatterplot(data=category_discounts, x='Discount', y='Profit', hue='Category', palette='Set1', s=100, legend=False)
plt.title('Average Discount vs Average Profit by Category')
plt.xlabel('Average Discount')
plt.ylabel('Average Profit')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# The scatter plot shows that the category with the highest average discount also has the lowest average profit, so it indicates that the more discount we give the profit decreases

# %% [markdown]
# -------

# %% [markdown]
# Quantity vs Profit Analysis

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Quantity', y='Profit', hue='Category', palette='Dark2', legend=False)
plt.title('Quantity Sold vs Profit')
plt.xlabel('Quantity')
plt.ylabel('Profit')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight :**
# The scatter plot shows that higher quantities which are sold always do not give high profits, especially in some of the categories  where large quantities are linked with low or even negative profits.
